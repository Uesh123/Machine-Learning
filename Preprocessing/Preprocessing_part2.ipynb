# %%
import pandas as pd
import numpy as np
import missingno as mso
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer

# %%
pd.set_option('display.max_columns',None)

# %%
df=pd.read_csv('C:\\Users\\saroj\\Documents\\machine lerning\\automobile.csv')
df.head()
# Out:
#    Unnamed: 0  symboling normalized-losses         make fuel-type aspiration  \
# 0           0          3                 ?  alfa-romero       gas        std
# 1           1          3                 ?  alfa-romero       gas        std
# 2           2          1                 ?  alfa-romero       gas        std
# 3           3          2               164         audi       gas        std
# 4           4          2               164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
# 3         four        sedan          fwd           front        99.8   176.6
# 4         four        sedan          4wd           front        99.4   176.6
#
# ...

# %%
df.replace('?',np.nan)
# Out:
#      Unnamed: 0  symboling normalized-losses         make fuel-type  \
# 0             0          3               NaN  alfa-romero       gas
# 1             1          3               NaN  alfa-romero       gas
# 2             2          1               NaN  alfa-romero       gas
# 3             3          2               164         audi       gas
# 4             4          2               164         audi       gas
# ..          ...        ...               ...          ...       ...
# 200         200         -1                95        volvo       gas
# 201         201         -1                95        volvo       gas
# 202         202         -1                95        volvo       gas
# 203         203         -1                95        volvo    diesel
# 204         204         -1                95        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  \
# 0          std          two  convertible          rwd           front
# ...

# %%
df.replace('?',np.nan,inplace=True)

# %%
mso.matrix(df,figsize=(15,5))
# Out:
# <AxesSubplot: >

# %%
df.shape[0]
# Out:
# 205

# %%
for col in df:
    print (f'{col:25}{df[col].nunique()}value')
# Out:
# Unnamed: 0               205value
# symboling                6value
# normalized-losses        51value
# make                     22value
# fuel-type                2value
# aspiration               2value
# num-of-doors             2value
# body-style               5value
# drive-wheels             3value
# engine-location          2value
# wheel-base               53value
# length                   75value
# width                    44value
# height                   49value
# curb-weight              171value
# engine-type              7value
# num-of-cylinders         7value
# engine-size              44value
# fuel-system              8value
# bore                     38value
# stroke                   36value
# compression-ratio        32value
# horsepower               59value
# peak-rpm                 23value
# city-mpg                 29value
# highway-mpg              30value
# price                    186value

# %% [markdown]
# using a loop to understand columns type

# %%
#using the loop

for col in df:
    df[col].value_counts().plot(kind='bar',title=f'{col} graph', figsize=(15,4))
    plt.show()

# %%
num_cols=['normalized-losses','wheel-base','length','width','height','curb-weight','engine-size',
'compression-ratio','bore','stroke','horsepower','peak-rpm','city-mpg', 'highway-mpg']
cat_cols =['symboling','make','fuel-type','aspiration','num-of-doors','body-style','engine-location',
'engine-type','num-of-cylinders','fuel-system','drive-wheels']

# %% [markdown]
# - imputing only numarical data

# %%
df=[num_cols]

# %%
mso.matrix(df[num_cols], figsize=(10,4))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 mso.matrix(df[num_cols], figsize=(10,4))
#
# TypeError: list indices must be integers or slices, not list

# %%
num_si = SimpleImputer()
df[num_cols] = num_si.fit_transform(df[num_cols])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 2
#       1 num_si = SimpleImputer()
# ----> 2 df[num_cols] = num_si.fit_transform(df[num_cols])
#
# TypeError: list indices must be integers or slices, not list
